# %%
import pandas as pd
import numpy as np
import requests
import matplotlib.pyplot as plt
import os

# %%
import sys
sys.path.append('C:/Users/bheim/PythonProjects/AMTDpy')

# %%
os.chdir("..")

# %%
import cryptocompare as crypto #my own user defined package for getting crypto prices
import cryptoconfig as ccf

# %%
import AMTDpy as td #my own user defined package for getting stock prices

# %%
spy = td.get_price_hist('SPY', 'daily', 1, "year", 2)

# %%
spy.head()
# Out:
#     close            datetime      high     low    open    volume symbol
# 0  259.11 2017-11-08 06:00:00  259.2200  258.15  258.47  50469579    SPY
# 1  258.17 2017-11-09 06:00:00  258.3900  256.36  257.73  95085497    SPY
# 2  258.09 2017-11-10 06:00:00  258.2926  257.37  257.73  59984662    SPY
# 3  258.33 2017-11-13 06:00:00  258.5900  257.27  257.31  50228648    SPY
# 4  257.73 2017-11-14 06:00:00  257.8500  256.52  257.41  61315152    SPY

# %%
qqq = td.get_price_hist('QQQ', 'daily', 1, "year", 2)

# %%
qqq.head()
# Out:
#     close            datetime      high     low    open    volume symbol
# 0  154.50 2017-11-08 06:00:00  154.5400  153.62  153.81  17373517    QQQ
# 1  153.69 2017-11-09 06:00:00  153.7700  152.11  153.26  40594482    QQQ
# 2  153.68 2017-11-10 06:00:00  153.8000  153.06  153.36  20150762    QQQ
# 3  153.87 2017-11-13 06:00:00  154.0693  153.10  153.12  12522399    QQQ
# 4  153.31 2017-11-14 06:00:00  153.5000  152.57  153.31  25173763    QQQ

# %%
gbtc = td.get_price_hist('GBTC', 'daily', 1, "year", 2)

# %%
gbtc.head()
# Out:
#        close            datetime       high       low       open    volume  \
# 0  10.120879 2017-11-08 06:00:00  10.604396  9.945055  10.288736  10491481
# 1  10.178571 2017-11-09 06:00:00  10.227912  9.890110  10.040604   3212937
# 2   9.670330 2017-11-10 06:00:00  10.126264  9.557582   9.669231   7694323
# 3   9.417582 2017-11-13 06:00:00   9.944725  9.406593   9.589890   6314763
# 4   8.791209 2017-11-14 06:00:00   9.560440  8.631868   9.560440   6932653
#
#   symbol
# 0   GBTC
# 1   GBTC
# 2   GBTC
# 3   GBTC
# 4   GBTC

# %%
xrp = crypto.get_coin_hist("XRP", "USD", 500, ccf.apikey, clip=1)

# %%
xrp.head()
# Out:
#     close    high     low    open                time   volumefrom  \
# 0  0.4685  0.4826  0.4537  0.4538 2018-06-29 20:00:00  49249801.71
# 1  0.4612  0.4696  0.4500  0.4685 2018-06-30 20:00:00  25721034.18
# 2  0.4899  0.4955  0.4528  0.4612 2018-07-01 20:00:00  52692864.19
# 3  0.4846  0.5193  0.4784  0.4897 2018-07-02 20:00:00  57688975.03
# 4  0.4920  0.5066  0.4753  0.4846 2018-07-03 20:00:00  42054793.68
#
#       volumeto
# 0  23040202.66
# 1  11796272.88
# 2  25177023.57
# 3  28730745.66
# 4  20670348.08

# %%
xrp.dtypes
# Out:
# close                float64
# high                 float64
# low                  float64
# open                 float64
# time          datetime64[ns]
# volumefrom           float64
# volumeto             float64
# dtype: object

# %%
btc = crypto.get_coin_hist("BTC", "USD", 500, ccf.apikey, clip=1)
btc.head()
# Out:
#      close     high      low     open                time  volumefrom  \
# 0  6385.38  6503.33  6194.51  6203.81 2018-06-29 20:00:00    65571.19
# 1  6339.04  6429.50  6262.72  6385.43 2018-06-30 20:00:00    40809.54
# 2  6615.66  6673.71  5537.86  6342.69 2018-07-01 20:00:00    73069.19
# 3  6509.58  6670.30  6473.48  6616.60 2018-07-02 20:00:00    54662.02
# 4  6590.06  6777.97  6411.13  6508.43 2018-07-03 20:00:00    62355.75
#
#        volumeto
# 0  4.192847e+08
# 1  2.597085e+08
# 2  4.659157e+08
# 3  3.563909e+08
# 4  4.122024e+08

# %%
eth = crypto.get_coin_hist("ETH", "USD", 500, ccf.apikey, clip=1)
eth.head()
# Out:
#     close    high     low    open                time  volumefrom  \
# 0  453.42  462.56  435.16  435.26 2018-06-29 20:00:00   374654.69
# 1  451.09  453.56  447.66  453.56 2018-06-30 20:00:00   461525.09
# 2  476.58  481.83  444.31  451.96 2018-07-01 20:00:00   420363.60
# 3  461.95  486.76  459.78  476.58 2018-07-02 20:00:00   386456.87
# 4  467.19  481.79  451.46  461.79 2018-07-03 20:00:00   349599.57
#
#        volumeto
# 0  1.684676e+08
# 1  2.081875e+08
# 2  1.953326e+08
# 3  1.823723e+08
# 4  1.632950e+08

# %%
ltc = crypto.get_coin_hist("LTC", "USD", 500, ccf.apikey, clip=1)
ltc.head()
# Out:
#    close   high    low   open                time  volumefrom      volumeto
# 0  81.16  83.33  80.07  79.04 2018-06-29 20:00:00  1008774.67  8.187032e+07
# 1  79.68  80.63  78.22  81.16 2018-06-30 20:00:00   988194.69  7.874107e+07
# 2  85.47  86.27  81.84  79.73 2018-07-01 20:00:00  1056007.52  9.026153e+07
# 3  84.88  87.81  83.78  85.49 2018-07-02 20:00:00  1242541.43  1.054730e+08
# 4  85.41  87.12  85.08  84.80 2018-07-03 20:00:00   951436.86  8.125954e+07

# %%
#convert dates to same datatype for joining/concatenating dataframes, and set as index

# %%
import datetime as dt

# %%
btc['time'] = btc['time'].astype('datetime64[D]')
btc= btc.set_index('time')
btc = btc.add_suffix('_btc')

# %%
eth['time'] = eth['time'].astype('datetime64[D]')
eth = eth.set_index('time')

# %%
eth = eth.add_suffix('_eth')

# %%
xrp['time'] = xrp['time'].astype('datetime64[D]')
xrp = xrp.set_index('time')

# %%
xrp = xrp.add_suffix('_xrp')

# %%
ltc['time'] = ltc['time'].astype('datetime64[D]')
ltc = ltc.set_index('time')

# %%
ltc = ltc.add_suffix('_ltc')

# %%
coins = pd.concat([btc, eth, xrp, ltc], axis = 1)

# %%
coins.head()
# Out:
#             close_btc  high_btc  low_btc  open_btc  volumefrom_btc  \
# time
# 2018-06-29    6385.38   6503.33  6194.51   6203.81        65571.19
# 2018-06-30    6339.04   6429.50  6262.72   6385.43        40809.54
# 2018-07-01    6615.66   6673.71  5537.86   6342.69        73069.19
# 2018-07-02    6509.58   6670.30  6473.48   6616.60        54662.02
# 2018-07-03    6590.06   6777.97  6411.13   6508.43        62355.75
#
#             volumeto_btc  close_eth  high_eth  low_eth  open_eth  \
# time
# 2018-06-29  4.192847e+08     453.42    462.56   435.16    435.26
# 2018-06-30  2.597085e+08     451.09    453.56   447.66    453.56
# 2018-07-01  4.659157e+08     476.58    481.83   444.31    451.96
# 2018-07-02  3.563909e+08     461.95    486.76   459.78    476.58
# 2018-07-03  4.122024e+08     467.19    481.79   451.46    461.79
#
#                 ...       low_xrp  open_xrp  volumefrom_xrp  volumeto_xrp  \
# time            ...
# 2018-06-29      ...        0.4537    0.4538     49249801.71   23040202.66
# 2018-06-30      ...        0.4500    0.4685     25721034.18   11796272.88
# 2018-07-01      ...        0.4528    0.4612     52692864.19   25177023.57
# 2018-07-02      ...        0.4784    0.4897     57688975.03   28730745.66
# 2018-07-03      ...        0.4753    0.4846     42054793.68   20670348.08
#
#             close_ltc  high_ltc  low_ltc  open_ltc  volumefrom_ltc  \
# time
# 2018-06-29      81.16     83.33    80.07     79.04      1008774.67
# 2018-06-30      79.68     80.63    78.22     81.16       988194.69
# 2018-07-01      85.47     86.27    81.84     79.73      1056007.52
# 2018-07-02      84.88     87.81    83.78     85.49      1242541.43
# 2018-07-03      85.41     87.12    85.08     84.80       951436.86
#
#             volumeto_ltc
# time
# 2018-06-29  8.187032e+07
# 2018-06-30  7.874107e+07
# 2018-07-01  9.026153e+07
# 2018-07-02  1.054730e+08
# 2018-07-03  8.125954e+07
#
# [5 rows x 24 columns]

# %%
coinps  = coins.filter(like='close')
coinps.head()
# Out:
#             close_btc  close_eth  close_xrp  close_ltc
# time
# 2018-06-29    6385.38     453.42     0.4685      81.16
# 2018-06-30    6339.04     451.09     0.4612      79.68
# 2018-07-01    6615.66     476.58     0.4899      85.47
# 2018-07-02    6509.58     461.95     0.4846      84.88
# 2018-07-03    6590.06     467.19     0.4920      85.41

# %%
#do the same for etfs/gbtc

# %%
spy.datetime = spy.datetime.astype('datetime64[D]')
spy = spy.set_index('datetime')

# %%
spy = spy.add_suffix('_spy')

# %%
qqq.datetime = qqq.datetime.astype('datetime64[D]')
qqq = qqq.set_index('datetime')

# %%
qqq = qqq.add_suffix('_qqq')

# %%
gbtc.datetime = gbtc.datetime.astype('datetime64[D]')
gbtc = gbtc.set_index('datetime')

# %%
gbtc = gbtc.add_suffix('_gbtc')

# %%
mkt = pd.concat([spy, qqq, gbtc], axis = 1)
mkt.head()
# Out:
#             close_spy  high_spy  low_spy  open_spy  volume_spy symbol_spy  \
# datetime
# 2017-11-08     259.11  259.2200   258.15    258.47    50469579        SPY
# 2017-11-09     258.17  258.3900   256.36    257.73    95085497        SPY
# 2017-11-10     258.09  258.2926   257.37    257.73    59984662        SPY
# 2017-11-13     258.33  258.5900   257.27    257.31    50228648        SPY
# 2017-11-14     257.73  257.8500   256.52    257.41    61315152        SPY
#
#             close_qqq  high_qqq  low_qqq  open_qqq  volume_qqq symbol_qqq  \
# datetime
# 2017-11-08     154.50  154.5400   153.62    153.81    17373517        QQQ
# 2017-11-09     153.69  153.7700   152.11    153.26    40594482        QQQ
# 2017-11-10     153.68  153.8000   153.06    153.36    20150762        QQQ
# 2017-11-13     153.87  154.0693   153.10    153.12    12522399        QQQ
# 2017-11-14     153.31  153.5000   152.57    153.31    25173763        QQQ
#
#             close_gbtc  high_gbtc  low_gbtc  open_gbtc  volume_gbtc  \
# datetime
# 2017-11-08   10.120879  10.604396  9.945055  10.288736     10491481
# 2017-11-09   10.178571  10.227912  9.890110  10.040604      3212937
# 2017-11-10    9.670330  10.126264  9.557582   9.669231      7694323
# 2017-11-13    9.417582   9.944725  9.406593   9.589890      6314763
# 2017-11-14    8.791209   9.560440  8.631868   9.560440      6932653
#
#            symbol_gbtc
# datetime
# 2017-11-08        GBTC
# 2017-11-09        GBTC
# 2017-11-10        GBTC
# 2017-11-13        GBTC
# 2017-11-14        GBTC

# %%
mktps = mkt.filter(like='close')
mktps.head()
# Out:
#             close_spy  close_qqq  close_gbtc
# datetime
# 2017-11-08     259.11     154.50   10.120879
# 2017-11-09     258.17     153.69   10.178571
# 2017-11-10     258.09     153.68    9.670330
# 2017-11-13     258.33     153.87    9.417582
# 2017-11-14     257.73     153.31    8.791209

# %%
coins_mkt = pd.concat([coinps, mktps], axis =1).dropna()
print(coins_mkt.shape)
coins_mkt.head()
# Out:
# (344, 7)
#             close_btc  close_eth  close_xrp  close_ltc  close_spy  close_qqq  \
# 2018-06-29    6385.38     453.42     0.4685      81.16     271.28     171.65
# 2018-07-02    6509.58     461.95     0.4846      84.88     271.86     172.80
# 2018-07-03    6590.06     467.19     0.4920      85.41     270.90     170.80
# 2018-07-05    6602.02     469.93     0.4764      83.12     273.11     172.92
# 2018-07-06    6758.08     485.81     0.4851      84.88     275.42     175.61
#
#             close_gbtc
# 2018-06-29        8.53
# 2018-07-02       10.20
# 2018-07-03       10.01
# 2018-07-05       10.05
# 2018-07-06       10.23

# %%
# %matplotlib inline

# %%
returns = pd.DataFrame(np.log(coins_mkt / coins_mkt.shift(1))).dropna()
returns.head()
# Out:
#             close_btc  close_eth  close_xrp  close_ltc  close_spy  close_qqq  \
# 2018-07-02   0.019264   0.018638   0.033788   0.044816   0.002136   0.006677
# 2018-07-03   0.012288   0.011279   0.015155   0.006225  -0.003537  -0.011642
# 2018-07-05   0.001813   0.005848  -0.032221  -0.027178   0.008125   0.012336
# 2018-07-06   0.023363   0.033234   0.018097   0.020953   0.008423   0.015437
# 2018-07-09  -0.069102  -0.115796  -0.091689  -0.111427   0.008964   0.008957
#
#             close_gbtc
# 2018-07-02    0.178798
# 2018-07-03   -0.018803
# 2018-07-05    0.003988
# 2018-07-06    0.017752
# 2018-07-09    0.006819

# %%
import seaborn as sns
sns.set_style('darkgrid')

# %%
sns.pairplot(returns)

# %%
##CRYPTO and EQUITIES NOT STRONGLY CORRELATED

# %%
for i in list(returns):
    sns.distplot(returns[str(i)])
    plt.show()
# Out:
# C:\Miniconda\envs\py3_plus\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
for i in list(returns):
    sns.distplot(returns[str(i)])
plt.legend(returns.columns)
# Out:
# C:\Miniconda\envs\py3_plus\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
import pandas as pd
import numpy as np
corr = returns.corr()
corr.style.background_gradient(cmap='coolwarm')
# Out:
# <style  type="text/css" >
#     #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col0 {
#             background-color:  #b40426;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col1 {
#             background-color:  #e9785d;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col2 {
#             background-color:  #f7b396;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col3 {
#             background-color:  #f18d6f;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col4 {
#             background-color:  #445acc;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col5 {
#             background-color:  #4b64d5;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col6 {
#             background-color:  #8fb1fe;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col0 {
#             background-color:  #e9785d;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col1 {
#             background-color:  #b40426;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col2 {
#             background-color:  #ed8366;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col3 {
#             background-color:  #e57058;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col4 {
#             background-color:  #4055c8;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col5 {
#             background-color:  #465ecf;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col6 {
#             background-color:  #7da0f9;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col0 {
#             background-color:  #f7b89c;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col1 {
#             background-color:  #ef886b;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col2 {
#             background-color:  #b40426;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col3 {
#             background-color:  #f6a385;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col4 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col5 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col6 {
#             background-color:  #6485ec;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow3_col0 {
#             background-color:  #f08b6e;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow3_col1 {
#             background-color:  #e46e56;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow3_col2 {
#             background-color:  #f49a7b;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow3_col3 {
#             background-color:  #b40426;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow3_col4 {
#             background-color:  #4b64d5;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow3_col5 {
#             background-color:  #536edd;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow3_col6 {
#             background-color:  #6f92f3;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow4_col0 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow4_col1 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow4_col2 {
#             background-color:  #4055c8;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow4_col3 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow4_col4 {
#             background-color:  #b40426;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow4_col5 {
#             background-color:  #c53334;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow4_col6 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow5_col0 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow5_col1 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow5_col2 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow5_col3 {
#             background-color:  #3b4cc0;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow5_col4 {
#             background-color:  #c53334;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow5_col5 {
#             background-color:  #b40426;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow5_col6 {
#             background-color:  #4358cb;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow6_col0 {
#             background-color:  #9abbff;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow6_col1 {
#             background-color:  #8caffe;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow6_col2 {
#             background-color:  #80a3fa;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow6_col3 {
#             background-color:  #7597f6;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow6_col4 {
#             background-color:  #506bda;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow6_col5 {
#             background-color:  #5f7fe8;
#         }    #T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow6_col6 {
#             background-color:  #b40426;
#         }</style>
# <table id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2f" >
# <thead>    <tr>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >close_btc</th>
#         <th class="col_heading level0 col1" >close_eth</th>
#         <th class="col_heading level0 col2" >close_xrp</th>
#         <th class="col_heading level0 col3" >close_ltc</th>
#         <th class="col_heading level0 col4" >close_spy</th>
#         <th class="col_heading level0 col5" >close_qqq</th>
#         <th class="col_heading level0 col6" >close_gbtc</th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2flevel0_row0" class="row_heading level0 row0" >close_btc</th>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col0" class="data row0 col0" >1</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col1" class="data row0 col1" >0.818492</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col2" class="data row0 col2" >0.653596</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col3" class="data row0 col3" >0.777266</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col4" class="data row0 col4" >-0.0346736</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col5" class="data row0 col5" >-0.0337113</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow0_col6" class="data row0 col6" >0.260898</td>
#     </tr>    <tr>
#         <th id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2flevel0_row1" class="row_heading level0 row1" >close_eth</th>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col0" class="data row1 col0" >0.818492</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col1" class="data row1 col1" >1</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col2" class="data row1 col2" >0.782599</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col3" class="data row1 col3" >0.839503</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col4" class="data row1 col4" >-0.0449832</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col5" class="data row1 col5" >-0.0476305</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow1_col6" class="data row1 col6" >0.213688</td>
#     </tr>    <tr>
#         <th id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2flevel0_row2" class="row_heading level0 row2" >close_xrp</th>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col0" class="data row2 col0" >0.653596</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col1" class="data row2 col1" >0.782599</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col2" class="data row2 col2" >1</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_380025a2dc2frow2_col3" class="data row2 col3" >0.723047</td>
#         <td id="T_d8a47b02_04f1_11ea_ad5d_3800

# %%
## NOT A LOT OF CORR OF RETURNS BETWEEN EQUITIES AND CRYPTO - LOOK AT VOLATILITY WHEN HAVE TIME

# %%
plt.figure(figsize =(12,10))
plt.plot(returns.dropna())
plt.legend(returns.columns)

# %%
import scipy.stats as stats

# %%
#rename columns for simplicity
returns.columns = returns.columns.str.replace('close_', '')
returns.head()
# Out:
#                  btc       eth       xrp       ltc       spy       qqq  \
# 2018-07-02  0.019264  0.018638  0.033788  0.044816  0.002136  0.006677
# 2018-07-03  0.012288  0.011279  0.015155  0.006225 -0.003537 -0.011642
# 2018-07-05  0.001813  0.005848 -0.032221 -0.027178  0.008125  0.012336
# 2018-07-06  0.023363  0.033234  0.018097  0.020953  0.008423  0.015437
# 2018-07-09 -0.069102 -0.115796 -0.091689 -0.111427  0.008964  0.008957
#
#                 gbtc
# 2018-07-02  0.178798
# 2018-07-03 -0.018803
# 2018-07-05  0.003988
# 2018-07-06  0.017752
# 2018-07-09  0.006819

# %%
#Attempt to determine Markowitz Efficient Frontier with monte carlo sim of portfolio weights

# %%
yr_returns = returns['2018-11-01':'2019-11-01']

# %%
#out of curiousity how normal are btc log returns among other cryptos
btc_prbplt = stats.probplot(yr_returns.btc, plot=plt)

# %%
# calculate daily and annual returns of the stocks
returns_daily = yr_returns
returns_annual = yr_returns.mean() * 250

# get daily and covariance of returns of the stock
cov_daily = returns_daily.cov()
cov_annual = cov_daily * 250

# %%
#List for storing the returns, volatility and weights sim portfolios
port_returns = []
port_volatility = []
sharpe_ratio = []
stock_weights = []

#set number of simulated portfolios
num_assets = len(list(yr_returns))
num_portfolios = 50000

# populate the empty lists with each portfolios returns,risk and weights
for single_portfolio in range(num_portfolios):
    weights = np.random.random(num_assets)
    weights /= np.sum(weights)
    returns = np.dot(weights, returns_annual)
    volatility = np.sqrt(np.dot(weights.T, np.dot(cov_annual, weights)))
    sharpe = returns / volatility
    sharpe_ratio.append(sharpe)
    port_returns.append(returns)
    port_volatility.append(volatility)
    stock_weights.append(weights)

# %%
# ceate a dict for the returns vol and sharpe
portfolio = {'Returns': port_returns,
             'Volatility': port_volatility,
             'Sharpe Ratio': sharpe_ratio}

# extend original dictionary to accomodate each ticker and weight in the portfolio
for counter,symbol in enumerate(list(yr_returns)):
    portfolio[symbol+' Weight'] = [Weight[counter] for Weight in stock_weights]

df = pd.DataFrame(portfolio)

# rename labels in the df
column_order = ['Returns', 'Volatility', 'Sharpe Ratio'] + [stock+' Weight' for stock in list(yr_returns)]

# reorder dataframe columns
df = df[column_order]



# find min Volatility & max sharpe values in the dataframe (df)
min_volatility = df['Volatility'].min()
max_sharpe = df['Sharpe Ratio'].max()

# use the min, max values to locate and create the two special portfolios
sharpe_portfolio = df.loc[df['Sharpe Ratio'] == max_sharpe]
min_variance_port = df.loc[df['Volatility'] == min_volatility]

# plot frontier, max sharpe & min Volatility values with a scatterplot
plt.style.use('seaborn-dark')
df.plot.scatter(x='Volatility', y='Returns', c='Sharpe Ratio',
                cmap='RdYlGn', edgecolors='black', figsize=(10, 8), grid=True)
plt.scatter(x=sharpe_portfolio['Volatility'], y=sharpe_portfolio['Returns'], c='red', marker='D', s=200)
plt.scatter(x=min_variance_port['Volatility'], y=min_variance_port['Returns'], c='blue', marker='D', s=200 )
plt.xlabel('Volatility (Std. Deviation)')
plt.ylabel('Expected Returns')
plt.title('Efficient Frontier')
plt.show()

# %%
#This looks nothing like your typical Efficient Frontier - need to run more sim portfolios

# %%
min_variance_port
# Out:
#         Returns  Volatility  Sharpe Ratio  btc Weight  eth Weight  xrp Weight  \
# 40113  0.166781    0.219731      0.759023    0.042467    0.087394    0.002168
#
#        ltc Weight  spy Weight  qqq Weight  gbtc Weight
# 40113    0.025953     0.35745     0.38251     0.102058

# %%
sharpe_portfolio
# Out:
#         Returns  Volatility  Sharpe Ratio  btc Weight  eth Weight  xrp Weight  \
# 25185  0.209218    0.235499      0.888406    0.142994    0.020196    0.010474
#
#        ltc Weight  spy Weight  qqq Weight  gbtc Weight
# 25185    0.010604    0.345008    0.343059     0.127666

# %%
#Both portfolios heavily weight SPY and QQQ for the returns :)

# %%
list(portfolio)
# Out:
# ['Returns',
#  'ltc Weight',
#  'Volatility',
#  'Sharpe Ratio',
#  'eth Weight',
#  'xrp Weight',
#  'btc Weight',
#  'spy Weight']

# %% [markdown]
# ### Value at Risk

# %%
import datetime
import numpy as np
from scipy.stats import norm


def var_cov_var(P, c, mu, sigma):
    """
    Variance-Covariance calculation of daily Value-at-Risk
    using confidence level c, with mean of returns mu
    and standard deviation of returns sigma, on a portfolio
    of value P.
    """
    alpha = norm.ppf(1-c, mu, sigma)
    return P - P*(alpha + 1)

# %%
#Run this for the sharpe portfolio

# %%
P= 100000 #starting cash of 100k

# %%
#get the shares of the portfolio based on the starting prices
pf_start = (sharpe_portfolio.filter(like='Weight') *P) / np.array(coins_mkt['2018-11-01':'2018-11-01'])
pf_start
# Out:
#        btc Weight  eth Weight   xrp Weight  ltc Weight  spy Weight  \
# 25185    2.236149    10.04211  2281.889224   20.621892  126.140798
#
#        qqq Weight  gbtc Weight
# 25185  199.383533  1922.674077

# %%
pf_value = (np.array(pf_start) * coins_mkt).sum(axis=1)
pf_value.head()
# Out:
# 2018-06-29    106418.759219
# 2018-07-02    110408.918368
# 2018-07-03    109784.149543
# 2018-07-05    110533.958875
# 2018-07-06    112272.356189
# dtype: float64

# %%
pf_returns = np.log(pf_value / pf_value.shift(1)).dropna()
pf_returns.head()
# Out:
# 2018-07-02    0.036809
# 2018-07-03   -0.005675
# 2018-07-05    0.006807
# 2018-07-06    0.015605
# 2018-07-09   -0.009500
# dtype: float64

# %%
P = 10000   # portfolio value
c = 0.99  # 99% confidence interval
 
mu = np.mean(pf_returns)
sigma = np.std(pf_returns)

var = var_cov_var(P, c, mu, sigma)
print("Value-at-Risk: $%0.2f" % var)
# Out:
# Value-at-Risk: $354.20

# %%
#plot the returns of the portfolio from the "training period"
pf_returns.cumsum().plot()

# %% [markdown]
# #### Experiment with some Monte Carlo Price Simulations as well as including them in VAR

# %%
xrp_price = coins_mkt['close_xrp']

# %%
spy_price = coins_mkt['close_spy']

# %%
len(xrp_price)
# Out:
# 344

# %%
#calculate the compound annual growth rate (CAGR) which 
#will give us our mean return input (mu) 
days = (xrp_price.index[-1] - xrp_price.index[0]).days
cagr = ((((xrp_price[-1]) / xrp_price[1])) ** (365.0/days)) - 1
print ('CAGR =',str(round(cagr,4)*100)+"%")
mu = cagr
# Out:
# CAGR = -33.14%

# %%
x_ret =  np.log(xrp_price/xrp_price.shift(1))
vol = x_ret.std() * np.sqrt(252)
print ("Annual Volatility =",str(round(vol,4)*100)+"%")
# Out:
# Annual Volatility = 93.5%

# %%
#Experimental Monte Carlo Sim of XRP

#Define Variables
S = xrp_price[-1] #starting stock price (i.e. last available real stock price)
T = 252 #Number of trading days


#create list of daily returns using random normal distribution from the returns mean and vol
daily_returns=np.random.normal((mu/T),vol/np.sqrt(T),T)+1

#set starting price and create price series generated by above random daily returns
price_list = [S]

for x in daily_returns:
    price_list.append(price_list[-1]*x)

#Generate Plots - price series and histogram of daily returns
plt.plot(price_list)
plt.show()
plt.hist(daily_returns-1, 100) #Note that we run the line plot and histogram separately, not simultaneously.
plt.show()

# %%
#Define a Function to be used in a package later on..

def run_montecarlo_pricesim(price, time_prd):
    #calculate the compound annual growth rate (CAGR) which 
    #will give us our mean return input (mu) 
    #days = (price.index[-1] - price.index[0]).days
    len(price)
    cagr = ((((price[-1]) / price[1])) ** (252.0/days)) - 1
    print ('CAGR =',str(round(cagr,4)*100)+"%")
    mu = cagr
    x_ret =  np.log(price/price.shift(1))
    vol = x_ret.std() * np.sqrt(252)
    print ("Annual Volatility =",str(round(vol,4)*100)+"%")
    
    
    #Define Variables
    S = price[-1] #starting stock price (i.e. last available real stock price)
    T = time_prd #Number of trading days
    #mu = 0.2309 #Return
    #vol = 0.4259 #Volatility

    #create list of daily returns using random normal distribution
    daily_returns=np.random.normal((mu/T),vol/np.sqrt(T),T)+1

    #set starting price and create price series generated by above random daily returns
    price_list = [S]

    for x in daily_returns:
        price_list.append(price_list[-1]*x)
    sim_ps = pd.Series(price_list)
    sim_ret =np.log(sim_ps / sim_ps.shift(1))
    print ("Simulation Log Returns =",str(round(sim_ret.sum(),4)))
    #Generate Plots - price series and histogram of daily returns
           
    plt.plot(price_list)
    plt.show()
    plt.hist(daily_returns-1, 100) #Note that we run the line plot and histogram separately, not simultaneously.
    plt.show()

# %%
#test function

# %%
run_montecarlo_pricesim(spy_price, 120)
# Out:
# CAGR = 6.7%
# Annual Volatility = 15.120000000000001%
# Simulation Log Returns = 0.2769

# %%
run_montecarlo_pricesim(coins_mkt['close_btc'], 250)
# Out:
# CAGR = 16.669999999999998%
# Annual Volatility = 71.81%
# Simulation Log Returns = 1.1285

# %%
#More monte carlo simulations

# %%
price = pd.Series(coins_mkt['close_btc'])

rets = np.log(price/price.shift(1))
rets = rets[1:]

daily_vol = rets.std()
daily_ret = rets.mean()

# %%
simulation_df = pd.DataFrame()

num_simulations = 1000  #takes a while if doing lots
predicted_days = 60

last_price = price.iloc[-1]

#Create Each Simulation as a Column in df
for x in range(num_simulations):
    count = 0  
    price_series = []
    price_series.append(last_price)
        
    #Series for Preditcted Days
    for i in range(predicted_days):
        if count == 251:
            break
        
        #price = price_series[count] + price_series[count] * (daily_ret + daily_vol * np.random.normal(0, 1))
        
        price = price_series[count] * (1 + np.random.normal(0, daily_vol))

        price_series.append(price)
        count += 1

    simulation_df[x] = price_series

plt.plot(simulation_df)
plt.show()

# %%
price_array = simulation_df.iloc[-1, :]
price_array = sorted(price_array, key=int) 

var0 = np.percentile(price_array, .90)
var =  np.percentile(price_array, .95)
var1 =  np.percentile(price_array, .99)
var2 =  np.percentile(price_array, .9999)

# %%
print("VaR at 90% Confidence: " + '${:,.2f}'.format(last_price - var0))
print("VaR at 95% Confidence: " + '${:,.2f}'.format(last_price - var))
print("VaR at 99% Confidence: " + '${:,.2f}'.format(last_price - var1))
print("VaR at 99.99% Confidence: " + '${:,.2f}'.format(last_price - var2))
# Out:
# VaR at 90% Confidence: $5,241.68
# VaR at 95% Confidence: $5,228.75
# VaR at 99% Confidence: $5,218.41
# VaR at 99.99% Confidence: $5,215.85

# %%
plt.figure(figsize=(12,7))
plt.hist(price_array, density = True)
plt.xlabel('Price')
plt.ylabel('Probability')
plt.title(r'Histogram of Simulated Stock Prices', fontsize=18, fontweight='bold')
plt.axvline(x=var, color='r', linestyle='--', label='Price at 95% Confidence Interval: ' + str(round(var, 2)))
plt.axvline(x=last_price, color='k', linestyle='--', label = 'Current Stock Price: ' + str(round(last_price, 2)))
plt.legend(loc='upper right', fontsize = 'x-small')

plt.show()

# %%
import seaborn as sns

# %%
sns.distplot(price_array)
# Out:
# C:\Miniconda\envs\py3_plus\lib\site-packages\scipy\stats\stats.py:1713: FutureWarning: Using a non-tuple sequence for multidimensional indexing is deprecated; use `arr[tuple(seq)]` instead of `arr[seq]`. In the future this will be interpreted as an array index, `arr[np.array(seq)]`, which will result either in an error or a different result.
#   return np.add.reduce(sorted[indexer] * weights, axis=axis) / sumval

# %%
#Explore with FB Prophet TS
# import error need to fix env

# %%
price = pd.Series(coins_mkt['close_btc'])
price.head()
# Out:
# 2018-06-29    6385.38
# 2018-07-02    6509.58
# 2018-07-03    6590.06
# 2018-07-05    6602.02
# 2018-07-06    6758.08
# Name: close_btc, dtype: float64

# %%
btc_ps = pd.DataFrame(price).reset_index()
btc_ps.columns = ['DS','Y']
btc_ps.head()
# Out:
#           DS        Y
# 0 2018-06-29  6385.38
# 1 2018-07-02  6509.58
# 2 2018-07-03  6590.06
# 3 2018-07-05  6602.02
# 4 2018-07-06  6758.08

# %%
import fbprophet
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-164-4f89f47c1bda> in <module>()
# ----> 1 import fbprophet
#
# C:\Miniconda\envs\py3_plus\lib\site-packages\fbprophet\__init__.py in <module>()
#       6 # of patent rights can be found in the PATENTS file in the same directory.
#       7
# ----> 8 from fbprophet.forecaster import Prophet
#       9
#      10 __version__ = '0.3'
#
# C:\Miniconda\envs\py3_plus\lib\site-packages\fbprophet\forecaster.py in <module>()
#      19 import pandas as pd
#      20 try:
# ---> 21     import pystan  # noqa F401
#      22 except ImportError:
#      23     logger.exception('You cannot run fbprophet without pystan installed')
#
# C:\Miniconda\envs\py3_plus\lib\site-packages\pystan\__init__.py in <module>()
#       7 import logging
#       8
# ----> 9 from pystan.api import stanc, stan
#      10 from pystan.misc import read_rdump, stan_rdump, stansummary
#      11 from pystan.model import StanModel
#
# C:\Miniconda\envs\py3_plus\lib\site-packages\pystan\api.py in <module>()
#      13 import pystan._api  # stanc wrapper
#      14 from pystan._compat import string_types, PY2
# ---> 15 from pystan.model import StanModel
#      16
#      17 logger = logging.getLogger('pystan')
#
# C:\Miniconda\envs\py3_plus\lib\site-packages\pystan\model.py in <module>()
#      36
#      37 import pystan.api
# ---> 38 import pystan.misc
#      39
#      40 logger = logging.getLogger('pystan')
#
# C:\Miniconda\envs\py3_plus\lib\site-packages\pystan\misc.py in <module>()
#      43     from pystan.external.scipy.mstats import mquantiles
#      44
# ---> 45 import pystan.chains
#      46 import pystan._misc
#      47 from pystan.constants import (MAX_UINT, sampling_algo_t, optim_algo_t,
#
# C:\Miniconda\envs\py3_plus\lib\site-packages\pystan\chains.py in <module>()
# ----> 1 import pystan._chains as _chains
#       2
#       3
#       4 def ess(sim, n):
#       5     """Calculate effective sample size
#
# AttributeError: module 'pystan' has no attribute '_chains'

# %%
model = Prophet(weekly_seasonality=True, yearly_seasonality=True)
model.add_seasonality('self_define_cycle', period=5, fourier_order=4)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# <ipython-input-163-26f66b80b3f6> in <module>()
# ----> 1 model = Prophet(weekly_seasonality=7, yearly_seasonality=252)
#       2 model.add_seasonality('self_define_cycle', period=5, fourier_order=4)
#
# NameError: name 'Prophet' is not defined

# %%
### more ideas - bootstrapping prices for price forecast, brownian motion for price forecast and VAR , boostrap by volatility, then run portfolio optimization with the underlying portfolio allocations and returns....
